# %%
import json
import pandas as pd
import requests

# %%
request = "https://api.modv.io/swagger/docs"

# %%
responce = requests.get(request).json()

# %%
def flatten_json(nested_json):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
df = pd.Series(flatten_json(responce)).to_frame()

# %%
 df
# Out:
#                                                                                 0
# swagger                                                                       2.0
# basePath                                                                        /
# x-aws-api-gateway-path                                                     /core/
# securityDefinitions_jwt_description                   Portal Middleware JWT Token
# securityDefinitions_jwt_type                                               apiKey
# ...                                                                           ...
# definitions_PasswordManager_properties_enterpri...                         string
# definitions_PasswordManagerPageResponse_propert...                          array
# definitions_PasswordManagerPageResponse_propert...  #/definitions/PasswordManager
# definitions_PasswordManagerPageResponse_propert...         #/definitions/PageInfo
# host                                                                  api.modv.io
#
# [3287 rows x 1 columns]

# %%
from itertools import chain, starmap

def flatten_json_iterative_solution(dictionary):
    """Flatten a nested json file"""

    def unpack(parent_key, parent_value):
        """Unpack one level of nesting in json file"""
        # Unpack one level only!!!
        
        if isinstance(parent_value, dict):
            for key, value in parent_value.items():
                temp1 = parent_key + '_' + key
                yield temp1, value
        elif isinstance(parent_value, list):
            i = 0 
            for value in parent_value:
                temp2 = parent_key + '_'+str(i) 
                i += 1
                yield temp2, value
        else:
            yield parent_key, parent_value    

            
    # Keep iterating until the termination condition is satisfied
    while True:
        # Keep unpacking the json file until all values are atomic elements (not dictionary or list)
        dictionary = dict(chain.from_iterable(starmap(unpack, dictionary.items())))
        # Terminate condition: not any value in the json file is dictionary or list
        if not any(isinstance(value, dict) for value in dictionary.values()) and \
           not any(isinstance(value, list) for value in dictionary.values()):
            break

    return dictionary

# %%
flatten_json_iterative_solution(responce)
# Out:
# {'swagger': '2.0',
#  'basePath': '/',
#  'x-aws-api-gateway-path': '/core/',
#  'securityDefinitions_jwt_description': 'Portal Middleware JWT Token',
#  'securityDefinitions_jwt_type': 'apiKey',
#  'securityDefinitions_jwt_name': 'jwt',
#  'securityDefinitions_jwt_in': 'header',
#  'info_title': 'My Own Document Vault API',
#  'info_version': '2.0.108',
#  'schemes_0': 'https',
#  'consumes_0': 'application/json',
#  'produces_0': 'application/json',
#  'paths_/core/healthcheck_get_summary': 'Healthcheck',
#  'paths_/core/healthcheck_get_description': 'Checks if the API is up and running',
#  'paths_/core/healthcheck_get_x-swagger-router-controller': 'healthcheck',
#  'paths_/core/healthcheck_get_operationId': 'get_coreHealth',
#  'paths_/core/healthcheck_get_tags_0': 'Healthcheck',
#  'paths_/core/healthcheck_get_responses_200_description': 'Success',
#  'paths_/core/login_get_summary': 'Login',
#  'paths_/core/login_get_description': '[Enterprise Only] Allows direct login to MODV',
#  'paths_/core/login_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/login_get_operationId': 'get_authenticationLogin',
#  'paths_/core/login_get_tags_0': 'Authentication',
#  'paths_/core/login_get_parameters_0_name': 'email',
#  'paths_/core/login_get_parameters_0_in': 'query',
#  'paths_/core/login_get_parameters_0_type': 'string',
#  'paths_/core/login_get_parameters_0_required': True,
#  'paths_/core/login_get_parameters_1_name': 'password',
#  'paths_/core/login_get_parameters_1_in': 'query',
#  'paths_/core/login_get_parameters_1_type': 'string',
#  'paths_/core/login_get_parameters_1_required': True,
#  'paths_/core/login_get_responses_200_description': 'Success',
#  'paths_/core/login_get_responses_200_schema_$ref': '#/definitions/LogonResponse',
#  'paths_/core/login_get_responses_default_description': 'Failed',
#  'paths_/core/login_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/refreshToken_get_summary': 'Refresh JWT',
#  'paths_/core/refreshToken_get_description': 'Requests a new JWT that is valid for the next 30 minutes',
#  'paths_/core/refreshToken_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/refreshToken_get_operationId': 'get_refreshToken',
#  'paths_/core/refreshToken_get_tags_0': 'Authentication',
#  'paths_/core/refreshToken_get_responses_200_description': 'Success',
#  'paths_/core/refreshToken_get_responses_200_schema_$ref': '#/definitions/LogonResponse',
#  'paths_/core/refreshToken_get_responses_default_description': 'Failed',
#  'paths_/core/refreshToken_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/personalAccessToken_get_summary': 'Get Personal Access Token',
#  'paths_/core/personalAccessToken_get_description': 'Gets a personal access token for the current user',
#  'paths_/core/personalAccessToken_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/personalAccessToken_get_operationId': 'get_personalAccessTokens',
#  'paths_/core/personalAccessToken_get_tags_0': 'Authentication',
#  'paths_/core/personalAccessToken_get_responses_200_description': 'Success',
#  'paths_/core/personalAccessToken_get_responses_200_schema_$ref': '#/definitions/PersonalAccessTokenResponse',
#  'paths_/core/personalAccessToken_get_responses_default_description': 'Failed',
#  'paths_/core/personalAccessToken_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/personalAccessToken_post_summary': 'Create Personal Access Token',
#  'paths_/core/personalAccessToken_post_description': 'Creates a personal access token for the current user',
#  'paths_/core/personalAccessToken_post_x-swagger-router-controller': 'authentication',
#  'paths_/core/personalAccessToken_post_operationId': 'post_personalAccessToken',
#  'paths_/core/personalAccessToken_post_tags_0': 'Authentication',
#  'paths_/core/personalAccessToken_post_parameters_0_name': 'personalAccessToken',
#  'paths_/core/personalAccessToken_post_parameters_0_required': True,
#  'paths_/core/personalAccessToken_post_parameters_0_in': 'body',
#  'paths_/core/personalAccessToken_post_parameters_0_schema_$ref': '#/definitions/PersonalAccessToken',
#  'paths_/core/personalAccessToken_post_responses_200_description': 'Success',
#  'paths_/core/personalAccessToken_post_responses_200_schema_$ref': '#/definitions/PersonalAccessToken',
#  'paths_/core/personalAccessToken_post_responses_default_description': 'Failed',
#  'paths_/core/personalAccessToken_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/personalAccessToken/{tokenId}_delete_summary': 'Delete Personal Access Token',
#  'paths_/core/personalAccessToken/{tokenId}_delete_description': 'Deletes a personal access token',
#  'paths_/core/personalAccessToken/{tokenId}_delete_x-swagger-router-controller': 'authentication',
#  'paths_/core/personalAccessToken/{tokenId}_delete_operationId': 'delete_personalAccessToken',
#  'paths_/core/personalAccessToken/{tokenId}_delete_tags_0': 'Authentication',
#  'paths_/core/personalAccessToken/{tokenId}_delete_parameters_0_name': 'tokenId',
#  'paths_/core/personalAccessToken/{tokenId}_delete_parameters_0_in': 'path',
#  'paths_/core/personalAccessToken/{tokenId}_delete_parameters_0_type': 'string',
#  'paths_/core/personalAccessToken/{tokenId}_delete_parameters_0_required': True,
#  'paths_/core/personalAccessToken/{tokenId}_delete_responses_200_description': 'Success',
#  'paths_/core/personalAccessToken/{tokenId}_delete_responses_default_description': 'Failed',
#  'paths_/core/personalAccessToken/{tokenId}_delete_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/oneTimeToken_get_summary': 'Get One Time Token',
#  'paths_/core/oneTimeToken_get_description': 'Gets a one time token for the current user',
#  'paths_/core/oneTimeToken_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/oneTimeToken_get_operationId': 'get_oneTimeToken',
#  'paths_/core/oneTimeToken_get_tags_0': 'Authentication',
#  'paths_/core/oneTimeToken_get_responses_200_description': 'Success',
#  'paths_/core/oneTimeToken_get_responses_200_schema_$ref': '#/definitions/LogonResponse',
#  'paths_/core/oneTimeToken_get_responses_default_description': 'Failed',
#  'paths_/core/oneTimeToken_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/authorize_get_summary': 'Authorize Auth0 User',
#  'paths_/core/authorize_get_description': 'Once a user has been authenticated with Auth0 they will be given a JWT token. This token is used to authorise against the MODV API and is exchanged for a JWT token that is used for all future requests.',
#  'paths_/core/authorize_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/authorize_get_operationId': 'get_authorize',
#  'paths_/core/authorize_get_tags_0': 'Authentication',
#  'paths_/core/authorize_get_responses_200_description': 'Success',
#  'paths_/core/authorize_get_responses_200_schema_$ref': '#/definitions/LogonResponse',
#  'paths_/core/authorize_get_responses_default_description': 'Failed',
#  'paths_/core/authorize_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/logout_delete_summary': 'Logout',
#  'paths_/core/logout_delete_description': 'Logs the current user out of the system',
#  'paths_/core/logout_delete_x-swagger-router-controller': 'authentication',
#  'paths_/core/logout_delete_operationId': 'logout',
#  'paths_/core/logout_delete_tags_0': 'Authentication',
#  'paths_/core/logout_delete_responses_200_description': 'Success',
#  'paths_/core/logout_delete_responses_200_schema_$ref': '#/definitions/LogoutResponse',
#  'paths_/core/logout_delete_responses_default_description': 'Failed',
#  'paths_/core/logout_delete_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/register_post_summary': 'User register',
#  'paths_/core/register_post_description': 'Registers a new user',
#  'paths_/core/register_post_x-swagger-router-controller': 'user',
#  'paths_/core/register_post_operationId': 'create_user',
#  'paths_/core/register_post_tags_0': 'User',
#  'paths_/core/register_post_parameters_0_name': 'user',
#  'paths_/core/register_post_parameters_0_required': True,
#  'paths_/core/register_post_parameters_0_in': 'body',
#  'paths_/core/register_post_parameters_0_schema_$ref': '#/definitions/User',
#  'paths_/core/register_post_responses_200_description': 'Success',
#  'paths_/core/register_post_responses_200_schema_$ref': '#/definitions/LogonResponse',
#  'paths_/core/register_post_responses_default_description': 'Failed',
#  'paths_/core/register_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/profile_get_summary': 'Get User Profile',
#  'paths_/core/profile_get_description': "Gets the current user's profile",
#  'paths_/core/profile_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/profile_get_operationId': 'get_profile',
#  'paths_/core/profile_get_tags_0': 'User',
#  'paths_/core/profile_get_responses_200_description': 'Success',
#  'paths_/core/profile_get_responses_200_schema_$ref': '#/definitions/User',
#  'paths_/core/profile_get_responses_default_description': 'Failed',
#  'paths_/core/profile_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/profile_put_summary': 'Update User Profile',
#  'paths_/core/profile_put_description': "Updates the current user's profile",
#  'paths_/core/profile_put_x-swagger-router-controller': 'authentication',
#  'paths_/core/profile_put_operationId': 'update_profile',
#  'paths_/core/profile_put_tags_0': 'User',
#  'paths_/core/profile_put_parameters_0_name': 'profile',
#  'paths_/core/profile_put_parameters_0_required': True,
#  'paths_/core/profile_put_parameters_0_in': 'body',
#  'paths_/core/profile_put_parameters_0_schema_$ref': '#/definitions/User',
#  'paths_/core/profile_put_responses_200_description': 'Success',
#  'paths_/core/profile_put_responses_200_schema_$ref': '#/definitions/User',
#  'paths_/core/profile_put_responses_default_description': 'Failed',
#  'paths_/core/profile_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/headerImage_put_summary': 'Update User Header Image',
#  'paths_/core/headerImage_put_description': "Updates the current user's header image",
#  'paths_/core/headerImage_put_x-swagger-router-controller': 'authentication',
#  'paths_/core/headerImage_put_operationId': 'upload_headerImage',
#  'paths_/core/headerImage_put_tags_0': 'User',
#  'paths_/core/headerImage_put_consumes_0': 'multipart/form-data',
#  'paths_/core/headerImage_put_parameters_0_name': 'headerImage',
#  'paths_/core/headerImage_put_parameters_0_in': 'formData',
#  'paths_/core/headerImage_put_parameters_0_type': 'file',
#  'paths_/core/headerImage_put_parameters_0_required': True,
#  'paths_/core/headerImage_put_responses_200_description': 'Success',
#  'paths_/core/headerImage_put_responses_200_schema_$ref': '#/definitions/User',
#  'paths_/core/headerImage_put_responses_default_description': 'Failed',
#  'paths_/core/headerImage_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/headerImage_get_summary': 'Get User Header Image',
#  'paths_/core/headerImage_get_description': "Gets the current user's header image",
#  'paths_/core/headerImage_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/headerImage_get_operationId': 'download_headerImage',
#  'paths_/core/headerImage_get_tags_0': 'User',
#  'paths_/core/headerImage_get_responses_200_description': 'Success',
#  'paths_/core/headerImage_get_responses_200_schema_type': 'file',
#  'paths_/core/headerImage_get_responses_default_description': 'Failed',
#  'paths_/core/headerImage_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/headerImage/stream_get_summary': 'Get User Header Image Stream',
#  'paths_/core/headerImage/stream_get_description': "Gets the current user's header image stream",
#  'paths_/core/headerImage/stream_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/headerImage/stream_get_operationId': 'download_headerImage_stream',
#  'paths_/core/headerImage/stream_get_tags_0': 'User',
#  'paths_/core/headerImage/stream_get_responses_200_description': 'Success',
#  'paths_/core/headerImage/stream_get_responses_200_schema_type': 'file',
#  'paths_/core/headerImage/stream_get_responses_default_description': 'Failed',
#  'paths_/core/headerImage/stream_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/headerImage/{imageId}_get_summary': 'Get User Header Image',
#  'paths_/core/headerImage/{imageId}_get_description': "Gets the current user's header image",
#  'paths_/core/headerImage/{imageId}_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/headerImage/{imageId}_get_operationId': 'get_headerImageById',
#  'paths_/core/headerImage/{imageId}_get_tags_0': 'User',
#  'paths_/core/headerImage/{imageId}_get_parameters_0_name': 'imageId',
#  'paths_/core/headerImage/{imageId}_get_parameters_0_in': 'path',
#  'paths_/core/headerImage/{imageId}_get_parameters_0_type': 'string',
#  'paths_/core/headerImage/{imageId}_get_parameters_0_required': True,
#  'paths_/core/headerImage/{imageId}_get_responses_200_description': 'Success',
#  'paths_/core/headerImage/{imageId}_get_responses_200_schema_type': 'file',
#  'paths_/core/headerImage/{imageId}_get_responses_default_description': 'Failed',
#  'paths_/core/headerImage/{imageId}_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/headerImage/{imageId}/stream_get_summary': 'Get User Header Image Stream',
#  'paths_/core/headerImage/{imageId}/stream_get_description': "Gets the current user's header image stream",
#  'paths_/core/headerImage/{imageId}/stream_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/headerImage/{imageId}/stream_get_operationId': 'get_headerImageById_stream',
#  'paths_/core/headerImage/{imageId}/stream_get_tags_0': 'User',
#  'paths_/core/headerImage/{imageId}/stream_get_parameters_0_name': 'imageId',
#  'paths_/core/headerImage/{imageId}/stream_get_parameters_0_in': 'path',
#  'paths_/core/headerImage/{imageId}/stream_get_parameters_0_type': 'string',
#  'paths_/core/headerImage/{imageId}/stream_get_parameters_0_required': True,
#  'paths_/core/headerImage/{imageId}/stream_get_responses_200_description': 'Success',
#  'paths_/core/headerImage/{imageId}/stream_get_responses_200_schema_type': 'file',
#  'paths_/core/headerImage/{imageId}/stream_get_responses_default_description': 'Failed',
#  'paths_/core/headerImage/{imageId}/stream_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/profile/diskUsage_get_summary': 'Get User Disk Usage',
#  'paths_/core/profile/diskUsage_get_description': "Gets the current user's disk usage",
#  'paths_/core/profile/diskUsage_get_x-swagger-router-controller': 'authentication',
#  'paths_/core/profile/diskUsage_get_operationId': 'diskUsage',
#  'paths_/core/profile/diskUsage_get_tags_0': 'User',
#  'paths_/core/profile/diskUsage_get_responses_200_description': 'Success',
#  'paths_/core/profile/diskUsage_get_responses_200_schema_$ref': '#/definitions/DiskUsage',
#  'paths_/core/profile/diskUsage_get_responses_default_description': 'Failed',
#  'paths_/core/profile/diskUsage_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/search_get_summary': 'Search',
#  'paths_/core/search_get_description': 'Searches for vaults, folders and documents',
#  'paths_/core/search_get_x-swagger-router-controller': 'search',
#  'paths_/core/search_get_operationId': 'search',
#  'paths_/core/search_get_tags_0': 'Search',
#  'paths_/core/search_get_parameters_0_name': 'term',
#  'paths_/core/search_get_parameters_0_required': False,
#  'paths_/core/search_get_parameters_0_in': 'query',
#  'paths_/core/search_get_parameters_0_type': 'string',
#  'paths_/core/search_get_parameters_1_name': 'pageNo',
#  'paths_/core/search_get_parameters_1_required': False,
#  'paths_/core/search_get_parameters_1_in': 'query',
#  'paths_/core/search_get_parameters_1_type': 'integer',
#  'paths_/core/search_get_parameters_2_name': 'itemsPerPage',
#  'paths_/core/search_get_parameters_2_required': False,
#  'paths_/core/search_get_parameters_2_in': 'query',
#  'paths_/core/search_get_parameters_2_type': 'integer',
#  'paths_/core/search_get_responses_200_description': 'Success',
#  'paths_/core/search_get_responses_200_schema_$ref': '#/definitions/SearchResults',
#  'paths_/core/search_get_responses_default_description': 'Failed',
#  'paths_/core/search_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/search/document_get_summary': 'Search Documents',
#  'paths_/core/search/document_get_description': 'Searches for documents',
#  'paths_/core/search/document_get_x-swagger-router-controller': 'search',
#  'paths_/core/search/document_get_operationId': 'search_documents',
#  'paths_/core/search/document_get_tags_0': 'Search',
#  'paths_/core/search/document_get_parameters_0_name': 'term',
#  'paths_/core/search/document_get_parameters_0_required': False,
#  'paths_/core/search/document_get_parameters_0_in': 'query',
#  'paths_/core/search/document_get_parameters_0_type': 'string',
#  'paths_/core/search/document_get_parameters_1_name': 'pageNo',
#  'paths_/core/search/document_get_parameters_1_required': False,
#  'paths_/core/search/document_get_parameters_1_in': 'query',
#  'paths_/core/search/document_get_parameters_1_type': 'integer',
#  'paths_/core/search/document_get_parameters_2_name': 'itemsPerPage',
#  'paths_/core/search/document_get_parameters_2_required': False,
#  'paths_/core/search/document_get_parameters_2_in': 'query',
#  'paths_/core/search/document_get_parameters_2_type': 'integer',
#  'paths_/core/search/document_get_responses_200_description': 'Success',
#  'paths_/core/search/document_get_responses_200_schema_$ref': '#/definitions/DocumentPageResponse',
#  'paths_/core/search/document_get_responses_default_description': 'Failed',
#  'paths_/core/search/document_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/search/recentlyDocuments_get_summary': 'Get Recently Updated Documents',
#  'paths_/core/search/recentlyDocuments_get_description': 'Gets the recently updated documents',
#  'paths_/core/search/recentlyDocuments_get_x-swagger-router-controller': 'search',
#  'paths_/core/search/recentlyDocuments_get_operationId': 'get_recently_documents',
#  'paths_/core/search/recentlyDocuments_get_tags_0': 'Search',
#  'paths_/core/search/recentlyDocuments_get_parameters_0_name': 'pageNo',
#  'paths_/core/search/recentlyDocuments_get_parameters_0_required': False,
#  'paths_/core/search/recentlyDocuments_get_parameters_0_in': 'query',
#  'paths_/core/search/recentlyDocuments_get_parameters_0_type': 'integer',
#  'paths_/core/search/recentlyDocuments_get_parameters_1_name': 'itemsPerPage',
#  'paths_/core/search/recentlyDocuments_get_parameters_1_required': False,
#  'paths_/core/search/recentlyDocuments_get_parameters_1_in': 'query',
#  'paths_/core/search/recentlyDocuments_get_parameters_1_type': 'integer',
#  'paths_/core/search/recentlyDocuments_get_responses_200_description': 'Success',
#  'paths_/core/search/recentlyDocuments_get_responses_200_schema_$ref': '#/definitions/DocumentPageResponse',
#  'paths_/core/search/recentlyDocuments_get_responses_default_description': 'Failed',
#  'paths_/core/search/recentlyDocuments_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/search/user_get_summary': 'Search Users',
#  'paths_/core/search/user_get_description': 'Searches for users',
#  'paths_/core/search/user_get_x-swagger-router-controller': 'user',
#  'paths_/core/search/user_get_operationId': 'search_user',
#  'paths_/core/search/user_get_tags_0': 'User',
#  'paths_/core/search/user_get_parameters_0_name': 'searchText',
#  'paths_/core/search/user_get_parameters_0_in': 'query',
#  'paths_/core/search/user_get_parameters_0_type': 'string',
#  'paths_/core/search/user_get_parameters_0_required': True,
#  'paths_/core/search/user_get_parameters_1_name': 'pageNo',
#  'paths_/core/search/user_get_parameters_1_in': 'query',
#  'paths_/core/search/user_get_parameters_1_type': 'number',
#  'paths_/core/search/user_get_parameters_1_required': False,
#  'paths_/core/search/user_get_parameters_2_name': 'itemsPerPage',
#  'paths_/core/search/user_get_parameters_2_in': 'query',
#  'paths_/core/search/user_get_parameters_2_type': 'number',
#  'paths_/core/search/user_get_parameters_2_required': False,
#  'paths_/core/search/user_get_responses_200_description': 'Success',
#  'paths_/core/search/user_get_responses_200_schema_$ref': '#/definitions/UserPageResponse',
#  'paths_/core/search/user_get_responses_default_description': 'Failed',
#  'paths_/core/search/user_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault_get_summary': 'Get Vaults',
#  'paths_/core/vault_get_description': 'Retrieves a list of all vault objects that the user has access to, the response object is organised into a structure of users. Where the first element in the array response is always yourself, and subsequent elements contain vaults/folders/documents that were permissioned to you.',
#  'paths_/core/vault_get_x-swagger-router-controller': 'vault',
#  'paths_/core/vault_get_operationId': 'get_vaults',
#  'paths_/core/vault_get_tags_0': 'Vault',
#  'paths_/core/vault_get_parameters_0_name': 'userId',
#  'paths_/core/vault_get_parameters_0_in': 'query',
#  'paths_/core/vault_get_parameters_0_type': 'string',
#  'paths_/core/vault_get_responses_200_description': 'Success',
#  'paths_/core/vault_get_responses_200_schema_type': 'array',
#  'paths_/core/vault_get_responses_200_schema_items_$ref': '#/definitions/VaultPageResponse',
#  'paths_/core/vault_get_responses_default_description': 'Failed',
#  'paths_/core/vault_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault_post_summary': 'Create Vault',
#  'paths_/core/vault_post_description': 'Create one or more root level objects. Only the name needs to be supplied and the name needs to be unique within the users account.',
#  'paths_/core/vault_post_x-swagger-router-controller': 'vault',
#  'paths_/core/vault_post_operationId': 'create_vaults',
#  'paths_/core/vault_post_tags_0': 'Vault',
#  'paths_/core/vault_post_parameters_0_name': 'vaults',
#  'paths_/core/vault_post_parameters_0_in': 'body',
#  'paths_/core/vault_post_parameters_0_schema_type': 'array',
#  'paths_/core/vault_post_parameters_0_schema_items_$ref': '#/definitions/Vault',
#  'paths_/core/vault_post_parameters_0_required': True,
#  'paths_/core/vault_post_responses_200_description': 'Success',
#  'paths_/core/vault_post_responses_200_schema_type': 'array',
#  'paths_/core/vault_post_responses_200_schema_items_$ref': '#/definitions/Vault',
#  'paths_/core/vault_post_responses_default_description': 'Failed',
#  'paths_/core/vault_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault_put_summary': 'Update Vault',
#  'paths_/core/vault_put_description': 'Update one or more root level objects. Only the name needs to be supplied and the name needs to be unique within the users account.',
#  'paths_/core/vault_put_x-swagger-router-controller': 'vault',
#  'paths_/core/vault_put_operationId': 'update_vaults',
#  'paths_/core/vault_put_tags_0': 'Vault',
#  'paths_/core/vault_put_parameters_0_name': 'vaults',
#  'paths_/core/vault_put_parameters_0_in': 'body',
#  'paths_/core/vault_put_parameters_0_schema_type': 'array',
#  'paths_/core/vault_put_parameters_0_schema_items_$ref': '#/definitions/Vault',
#  'paths_/core/vault_put_parameters_0_required': True,
#  'paths_/core/vault_put_responses_200_description': 'Success',
#  'paths_/core/vault_put_responses_200_schema_type': 'array',
#  'paths_/core/vault_put_responses_200_schema_items_$ref': '#/definitions/Vault',
#  'paths_/core/vault_put_responses_default_description': 'Failed',
#  'paths_/core/vault_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault_delete_x-swagger-router-controller': 'vault',
#  'paths_/core/vault_delete_operationId': 'delete_vaults',
#  'paths_/core/vault_delete_tags_0': 'Vault',
#  'paths_/core/vault_delete_parameters_0_name': 'vaultId',
#  'paths_/core/vault_delete_parameters_0_in': 'query',
#  'paths_/core/vault_delete_parameters_0_type': 'array',
#  'paths_/core/vault_delete_parameters_0_items_type': 'string',
#  'paths_/core/vault_delete_parameters_0_required': True,
#  'paths_/core/vault_delete_responses_200_description': 'Success',
#  'paths_/core/vault_delete_responses_default_description': 'Failed',
#  'paths_/core/vault_delete_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}_get_x-swagger-router-controller': 'vault',
#  'paths_/core/vault/{vaultId}_get_operationId': 'get_vault',
#  'paths_/core/vault/{vaultId}_get_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}_get_responses_200_schema_$ref': '#/definitions/Vault',
#  'paths_/core/vault/{vaultId}_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}_put_x-swagger-router-controller': 'vault',
#  'paths_/core/vault/{vaultId}_put_operationId': 'update_vault',
#  'paths_/core/vault/{vaultId}_put_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}_put_parameters_1_name': 'vault',
#  'paths_/core/vault/{vaultId}_put_parameters_1_in': 'body',
#  'paths_/core/vault/{vaultId}_put_parameters_1_schema_$ref': '#/definitions/Vault',
#  'paths_/core/vault/{vaultId}_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}_put_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}_put_responses_200_schema_$ref': '#/definitions/Vault',
#  'paths_/core/vault/{vaultId}_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}_delete_x-swagger-router-controller': 'vault',
#  'paths_/core/vault/{vaultId}_delete_operationId': 'delete_vault',
#  'paths_/core/vault/{vaultId}_delete_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}_delete_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}_delete_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}_delete_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}_delete_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}_delete_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}_delete_responses_200_schema_$ref': '#/definitions/Vault',
#  'paths_/core/vault/{vaultId}_delete_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}_delete_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/archiver_get_x-swagger-router-controller': 'vault',
#  'paths_/core/vault/{vaultId}/archiver_get_operationId': 'get_vault_archiver',
#  'paths_/core/vault/{vaultId}/archiver_get_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}/archiver_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/archiver_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/archiver_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/archiver_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/archiver_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/archiver_get_responses_200_schema_type': 'file',
#  'paths_/core/vault/{vaultId}/archiver_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/archiver_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/permissions_get_x-swagger-router-controller': 'vault',
#  'paths_/core/vault/{vaultId}/permissions_get_operationId': 'get_vault_permissions',
#  'paths_/core/vault/{vaultId}/permissions_get_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}/permissions_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/permissions_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/permissions_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/permissions_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/permissions_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/permissions_get_responses_200_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/permissions_get_responses_200_schema_items_$ref': '#/definitions/Permission',
#  'paths_/core/vault/{vaultId}/permissions_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/permissions_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/permissions_put_x-swagger-router-controller': 'vault',
#  'paths_/core/vault/{vaultId}/permissions_put_operationId': 'update_vault_permissions',
#  'paths_/core/vault/{vaultId}/permissions_put_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_1_name': 'permissions',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_1_in': 'body',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_1_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_1_schema_items_$ref': '#/definitions/Permission',
#  'paths_/core/vault/{vaultId}/permissions_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/permissions_put_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/permissions_put_responses_200_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/permissions_put_responses_200_schema_items_$ref': '#/definitions/Permission',
#  'paths_/core/vault/{vaultId}/permissions_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/permissions_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders_get_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders_get_operationId': 'get_folders',
#  'paths_/core/vault/{vaultId}/folders_get_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders_get_parameters_1_name': 'parentId',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_1_in': 'query',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders_get_parameters_1_required': False,
#  'paths_/core/vault/{vaultId}/folders_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders_get_responses_200_schema_$ref': '#/definitions/FolderPageResponse',
#  'paths_/core/vault/{vaultId}/folders_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders_post_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders_post_operationId': 'create_folders',
#  'paths_/core/vault/{vaultId}/folders_post_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders_post_parameters_1_name': 'folders',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_1_in': 'body',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_1_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_1_schema_items_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders_post_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders_post_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders_post_responses_200_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders_post_responses_200_schema_items_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders_post_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders_put_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders_put_operationId': 'update_folders',
#  'paths_/core/vault/{vaultId}/folders_put_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders_put_parameters_1_name': 'folders',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_1_in': 'body',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_1_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_1_schema_items_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders_put_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders_put_responses_200_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders_put_responses_200_schema_items_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders_delete_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders_delete_operationId': 'delete_folders',
#  'paths_/core/vault/{vaultId}/folders_delete_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_1_in': 'query',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_1_type': 'array',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_1_items_type': 'string',
#  'paths_/core/vault/{vaultId}/folders_delete_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders_delete_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders_delete_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders_delete_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_operationId': 'get_folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_responses_200_schema_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_operationId': 'delete_folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_responses_200_schema_$ref': '#/definitions/Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_delete_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_operationId': 'update_folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_2_name': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_2_in': 'body',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_2_schema_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_responses_200_schema_$ref': '#/definitions/Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders/{folderId}_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_operationId': 'get_folder_contents',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_2_name': 'sorts',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_2_in': 'query',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_2_type': 'array',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_2_items_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_2_required': False,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_name': 'type',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_in': 'query',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_enum_0': 'document',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_enum_1': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_enum_2': 'all',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_3_required': False,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_4_name': 'pageNo',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_4_type': 'integer',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_4_in': 'query',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_4_default': 0,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_4_required': False,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_5_name': 'itemsPerPage',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_5_in': 'query',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_5_type': 'integer',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_5_default': 20,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_parameters_5_required': False,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_responses_200_schema_$ref': '#/definitions/FolderContent',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/contents_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/folders/archiver_get_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/folders/archiver_get_operationId': 'get_folder_archiver',
#  'paths_/core/vault/folders/archiver_get_tags_0': 'Vault',
#  'paths_/core/vault/folders/archiver_get_parameters_0_name': 'folderIds',
#  'paths_/core/vault/folders/archiver_get_parameters_0_in': 'query',
#  'paths_/core/vault/folders/archiver_get_parameters_0_type': 'array',
#  'paths_/core/vault/folders/archiver_get_parameters_0_items_type': 'string',
#  'paths_/core/vault/folders/archiver_get_parameters_0_required': True,
#  'paths_/core/vault/folders/archiver_get_responses_200_description': 'Success',
#  'paths_/core/vault/folders/archiver_get_responses_200_schema_type': 'file',
#  'paths_/core/vault/folders/archiver_get_responses_default_description': 'Failed',
#  'paths_/core/vault/folders/archiver_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_operationId': 'get_folder_permissions',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_responses_200_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_responses_200_schema_items_$ref': '#/definitions/Permission',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_operationId': 'update_folder_permissions',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_tags_0': 'Folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_2_name': 'permissions',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_2_in': 'body',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_2_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_2_schema_items_$ref': '#/definitions/Permission',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_responses_200_description': 'Success',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_responses_200_schema_type': 'array',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_responses_200_schema_items_$ref': '#/definitions/Permission',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/permissions_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/tree_get_x-swagger-router-controller': 'folder',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/tree_get_operationId': 'get_tree',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/tree_get_tags_0': 'Vault',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/tree_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/folders/{folderId}/tree_get_parameters_0_in': 'path',
# ...
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_description': 'Needed for Element-UI remove this once possible',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_consumes_0': 'multipart/form-data',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_1_name': 'documentId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_2_name': 'file',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_2_in': 'formData',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_2_type': 'file',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_3_name': 'ocrText',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_3_in': 'formData',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_parameters_3_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_responses_200_description': 'File contents',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_responses_200_schema_$ref': '#/definitions/Document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_operationId': 'update_document_file',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_consumes_0': 'multipart/form-data',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_1_name': 'documentId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_2_name': 'file',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_2_in': 'formData',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_2_type': 'file',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_3_name': 'ocrText',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_3_in': 'formData',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_parameters_3_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_responses_200_description': 'File contents',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_responses_200_schema_$ref': '#/definitions/Document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/file_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_operationId': 'get_public_link_document_details',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_1_name': 'documentId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_2_name': 'uuid',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_2_in': 'query',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_2_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_3_name': 'token',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_3_in': 'query',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_3_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_3_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_4_name': 'publicLinkPassword',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_4_in': 'query',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_parameters_4_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_responses_200_description': 'File contents',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_responses_200_schema_type': 'file',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_get_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_operationId': 'create_public_link',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_1_name': 'documentId',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_2_name': 'publicLinkRequest',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_2_in': 'body',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_2_schema_$ref': '#/definitions/PublicLinkRequest',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_responses_200_description': 'public link',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_responses_200_schema_$ref': '#/definitions/PublicLink',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/documents/{documentId}/publicLink_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_operationId': 'create_document_file_binary',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_consumes_0': 'application/octet-stream',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_2_name': 'mimetype',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_2_in': 'query',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_2_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_3_name': 'name',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_3_in': 'query',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_3_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_3_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_4_name': 'file',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_4_in': 'body',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_4_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_4_schema_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_parameters_4_schema_format': 'byte',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_responses_200_description': 'File contents',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_responses_200_schema_$ref': '#/definitions/Document',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/{folderId}/file/binary_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_operationId': 'create_document_file_legacy',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_consumes_0': 'multipart/form-data',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_consumes_1': 'application/octet-stream',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_2_name': 'file',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_2_in': 'formData',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_2_type': 'file',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_responses_200_description': 'File contents',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_responses_200_schema_$ref': '#/definitions/Document',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/{folderId}/file_put_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_operationId': 'create_document_file',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_consumes_0': 'multipart/form-data',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_consumes_1': 'application/octet-stream',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_1_name': 'folderId',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_1_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_1_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_1_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_2_name': 'file',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_2_in': 'formData',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_2_type': 'file',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_parameters_2_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_responses_200_description': 'File contents',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_responses_200_schema_$ref': '#/definitions/Document',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_responses_default_description': 'Failed',
#  'paths_/core/vault/{vaultId}/{folderId}/file_post_responses_default_schema_$ref': '#/definitions/Error',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_x-swagger-router-controller': 'document',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_operationId': 'create_document_file_chunk',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_tags_0': 'Document',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_consumes_0': 'multipart/form-data',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_consumes_1': 'application/octet-stream',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_parameters_0_name': 'vaultId',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_parameters_0_in': 'path',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_parameters_0_type': 'string',
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_parameters_0_required': True,
#  'paths_/core/vault/{vaultId}/{folderId}/upload/chunk_post_parameters_1_name': 'folderId',
#  ...}

# %%
df = pd.Series(flatten_json_iterative_solution(responce)).to_frame()
